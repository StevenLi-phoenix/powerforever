# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import itertools as it

# %%
batteryConfig = pd.read_csv("BatteriesCSV.csv")
batteryConfig
# Out:
#                                                 Name  LCOE($/kWh)  \
# 0  Ultimate Power 12V 100Ah Lithium-Ion (LiFePO4)...   621.093750
# 1                            Deka Solar 8GCC2 6V 198   311.864400
# 2                           Trojan L-16 -SPRE 6V 415   196.800000
# 3                               Discover AES 7.4 kWh   875.405410
# 4                                Electriq PowerPod 2  1300.000000
# 5                                  Tesla Powerwall+    629.629630
# 6  ASNHJH 12V 300Ah LiFePO4 Battery Deep Cycle Ba...   642.986979
# 7     FREEDOH 72V 45AH Electrical Motorcycle Battery   430.722222
# 8   RIYIFER Class-A 3.2V 310Ah LiFePO4 Cells Battery   617.404234
# 9        ZJDU 48V 65AH Lithium Ion / Lifepo4 Battery  1076.887821
#
#    Power Density(W/in3)  Energy Density(kWh/lbs) Life span  \
# 0              1.877604                 0.040000         7
# 1              0.061771                 0.017353         4
# 2              0.133723                 0.021186         3
# ...

# %%
iteration = []
for i in range(1,len(batteryConfig)):
    for e in it.combinations_with_replacement(batteryConfig.values, i):
        iteration.append(e)

# %%
iteration[10000]
# Out:
# (array(['Ultimate Power 12V 100Ah Lithium-Ion (LiFePO4) Battery',
#         621.09375, 1.877603708, 0.04, '7', '93%', 1.28, 795.0],
#        dtype=object),
#  array(['Ultimate Power 12V 100Ah Lithium-Ion (LiFePO4) Battery',
#         621.09375, 1.877603708, 0.04, '7', '93%', 1.28, 795.0],
#        dtype=object),
#  array(['FREEDOH 72V 45AH Electrical Motorcycle Battery', 430.7222222,
#         1.386123842, 0.081646627, '6 years', '94%', 3.24, 1395.54],
#        dtype=object),
#  array(['RIYIFER Class-A 3.2V 310Ah LiFePO4 Cells Battery', 617.4042339,
#         0.422088644, 0.359970905, '8 years', '94%', 3.968, 2449.86],
#        dtype=object),
#  array(['RIYIFER Class-A 3.2V 310Ah LiFePO4 Cells Battery', 617.4042339,
#         0.422088644, 0.359970905, '8 years', '94%', 3.968, 2449.86],
#        dtype=object),
#  array(['ZJDU 48V 65AH Lithium Ion / Lifepo4 Battery', 1076.887821,
#         3.404866111, 0.054431084, '9 years', '95%', 3.12, 3359.89],
#        dtype=object),
# ...

# %%
battery_dic = {}
for item in iteration:
    battery_obj = {}
    for i in batteryConfig.keys():
        battery_obj["Name"] = []
        battery_obj["LCOE($/kWh)"] = 
        battery_obj["Power Density(W/in3)"] = 
        battery_obj["Energy Density(kWh/lbs)"] = 
        battery_obj["Life span"] = 
        battery_obj["Round-Trip Efficiency (%) "] = 
        battery_obj["Usabe Capacity(kWh)"] = 
        battery_obj["Cost($)"] = []

# %%
batteryConfig.keys()
# Out:
# Index(['Name', 'LCOE($/kWh)', 'Power Density(W/in3)',
#        'Energy Density(kWh/lbs)', 'Life span', 'Round-Trip Efficiency (%) ',
#        'Usabe Capacity(kWh)', 'Cost($)'],
#       dtype='object')
